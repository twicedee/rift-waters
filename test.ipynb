# %%
import ee
from src.acquisition.roads_acquisition import RoadsAcquisition
from config import get_roi_by_name
ee.Initialize(project="riftwaters")
roi = get_roi_by_name("bogoria")
RoadsAcquisition(region="bogoria").acquire_roads(roi)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
#   ⬇️ Downloading OSM roads for bogoria...
#   📝 Metadata saved to dataset/bogoria/metadata/bogoria_roads.json and dataset/bogoria/metadata/bogoria_roads.csv
#   ✅ 158 road segments saved to dataset/bogoria/raw/roads/bogoria_roads.gpkg
# 'dataset/bogoria/raw/roads/bogoria_roads.gpkg'
